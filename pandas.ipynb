# %% [markdown]
# <a href="https://colab.research.google.com/github/jasur-ben-blip/ai_foundation/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pandas

# %%
import pandas as pd

# %%
print(pd.__version__)
# Out:
# 2.2.2

# %%
mydataset = {
    'cars': ["BMW", "Volvo", "Ford", "Tesla", "Ferrari", "Ford", "BMW"],
    'counts': [3, 7, 2, 2, 5, 6, 1]
}

df = pd.DataFrame(mydataset)
print(df)
# Out:
#       cars  counts
# 0      BMW       3
# 1    Volvo       7
# 2     Ford       2
# 3    Tesla       2
# 4  Ferrari       5
# 5     Ford       6
# 6      BMW       1

# %%
df.head() # default 5 rows # ketma-ketlikda
# Out:
#       cars  counts
# 0      BMW       3
# 1    Volvo       7
# 2     Ford       2
# 3    Tesla       2
# 4  Ferrari       5

# %%
df.tail() # oxiridan 5 ta ni korsatadi # default 5 rows
# Out:
#       cars  counts
# 2     Ford       2
# 3    Tesla       2
# 4  Ferrari       5
# 5     Ford       6
# 6      BMW       1

# %%
df.shape
# Out:
# (7, 2)

# %%
df.columns
# Out:
# Index(['cars', 'counts'], dtype='object')

# %%
df.dtypes
# Out:
# cars      object
# counts     int64
# dtype: object

# %%
print(df)
# Out:
#       cars  counts
# 0      BMW       3
# 1    Volvo       7
# 2     Ford       2
# 3    Tesla       2
# 4  Ferrari       5
# 5     Ford       6
# 6      BMW       1

# %%
df.describe() # numerical colums only
# Out:
#          counts
# count  7.000000
# mean   3.714286
# std    2.288689
# min    1.000000
# 25%    2.000000
# 50%    3.000000
# 75%    5.500000
# max    7.000000

# %%
df.iloc[1:]
# Out:
#       cars  counts
# 1    Volvo       7
# 2     Ford       2
# 3    Tesla       2
# 4  Ferrari       5
# 5     Ford       6
# 6      BMW       1

# %%
df.loc[:, "cars"]
# Out:
# 0        BMW
# 1      Volvo
# 2       Ford
# 3      Tesla
# 4    Ferrari
# 5       Ford
# 6        BMW
# Name: cars, dtype: object

# %%
df[df["counts"] >= 3] #filtring
# Out:
#       cars  counts
# 0      BMW       3
# 1    Volvo       7
# 4  Ferrari       5
# 5     Ford       6

# %%
df[df["cars"] == "BMW"] # filtring
# Out:
#   cars  counts
# 0  BMW       3
# 6  BMW       1

# %%
df.mean(numeric_only=True)
# Out:
# counts    3.714286
# dtype: float64

# %%
df["counts"].mean()
# Out:
# np.float64(3.7142857142857144)

# %%
df.sum()
# Out:
# cars      BMWVolvoFordTeslaFerrariFordBMW
# counts                                 26
# dtype: object

# %%
df.min()
# Out:
# cars      BMW
# counts      1
# dtype: object

# %%
df.max()
# Out:
# cars      Volvo
# counts        7
# dtype: object

# %%
df.median(numeric_only=True)
# Out:
# counts    3.0
# dtype: float64

# %%
df.count()
# Out:
# cars      7
# counts    7
# dtype: int64

# %%
df.std(numeric_only=True)
# Out:
# counts    2.288689
# dtype: float64

# %%
data_with_missing = {
    "cars": ["BMW", "Volvo", None, "Tesla", "Ferrari", None, "Ford"],
    "counts": [3, 7, None, 2, 5, 9, None,]
}

df_missing = pd.DataFrame(data_with_missing)

print(df_missing)
# Out:
#       cars  counts
# 0      BMW     3.0
# 1    Volvo     7.0
# 2     None     NaN
# 3    Tesla     2.0
# 4  Ferrari     5.0
# 5     None     9.0
# 6     Ford     NaN

# %%
df_missing.isnull().sum()
# Out:
# cars      2
# counts    2
# dtype: int64

# %%
df_missing.dropna(subset=["cars"])
# Out:
#       cars  counts
# 0      BMW     3.0
# 1    Volvo     7.0
# 3    Tesla     2.0
# 4  Ferrari     5.0
# 6     Ford     NaN

# %%
df_missing.fillna("unknown")
# Out:
#       cars   counts
# 0      BMW      3.0
# 1    Volvo      7.0
# 2  unknown  unknown
# 3    Tesla      2.0
# 4  Ferrari      5.0
# 5  unknown      9.0
# 6     Ford  unknown

# %%
df = pd.read_csv("Titanic-Dataset.csv")

df.head(10)

# df.pd.read_excel("Titanic-Dataset.xlsx")
# df.pd.read_json("Titanic-Dataset.json")
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
df.to_excel("output.xlsx")

# %%
# Series => 1D
cars = pd.Series(["BMW", "Tesla", "Ferrari"])
print(cars)
# Out:
# 0        BMW
# 1      Tesla
# 2    Ferrari
# dtype: object

# %%
cars_series = data_with_missing['cars']
print(cars_series)
# Out:
# ['BMW', 'Volvo', None, 'Tesla', 'Ferrari', None, 'Ford']
